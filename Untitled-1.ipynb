# %%
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
import re

def create_distribution(response, frequency, suptitle):
    total = sum(frequency)
    percentages = [(freq / total * 100) for freq in frequency]

    # Get a colormap and normalize it to the number of segments
    cmap = get_cmap('tab20c')
    colors = cmap(range(len(response)))

    fig, (ax1, ax2) = plt.subplots(2,1, figsize=(8, 12))
    ax1.pie(percentages, labels=response, autopct='%1.1f%%', startangle=90, colors=colors, counterclock=True, wedgeprops={'edgecolor': 'gray'})
    ax1.set_title('Pie Chart')
    ax1.legend(response, loc='upper left', bbox_to_anchor=(0.95, 1), title="Response", fontsize=8)
    

    
    ax2.bar(response, frequency, color='skyblue')  # Use bar for vertical bars
    ax2.set_ylabel('Frequency (n)')
    ax2.set_xlabel('Response')
    ax2.set_title('Bar Chart')

    for i, freq in enumerate(frequency):
        ax2.text(response[i], freq + 1, str(freq), ha='center', va='bottom')

    plt.xticks(rotation=0)  # Rotate x-axis labels to be vertical

    sanitized_filename = re.sub(r'[\/:*?<>|]', '_', suptitle)
    file = f"{sanitized_filename}"
    plt.suptitle(suptitle, fontsize=14)
    plt.tight_layout()
    plt.savefig(sanitized_filename)
    plt.show()





table_data = [
    {
        "table_name": "Age of Mothers",
        "response": ["21-25 years", "25-30 years", "30-35 years"],
        "frequency": [30, 25, 45],
        "suptitle": "Age of Mothers"
    },
       {
        "table_name": "Do you have a health condition that prevents you from breastfeeding?",
        "response": ["Yes", "No"],
        "frequency": [16, 84],
        "suptitle": "Do you have a health condition that prevents you from breastfeeding?"
    },
    {
        "table_name": "Educational Level",
        "response": ["Primary", "JHS", "SHS", "Tertiary", "Other (specify)"],
        "frequency": [0, 0, 25, 70, 5],
        "suptitle": "Educational Level"
    },
    {
        "table_name": "Years of Teaching of Participants",
        "response": ["1 year", "2 years", "3 years", "4 years", "5 years"],
        "frequency": [6, 19, 34, 24, 17],
        "suptitle": "Years of Teaching of Participants"
    },
    {
        "table_name": "Grade Level Participants Teach",
        "response": ["Nursery", "Kindergarten", "Basic 1", "Basic 2", "Basic 3", "Basic 4", "Basic 5"],
        "frequency": [37, 21, 16, 6, 7, 8, 5],
        "suptitle": "Grade Level Participants Teach"
    },
    {
        "table_name": "Marital Status",
        "response": ["Single", "Married", "Divorced", "Widowed", "Separated"],
        "frequency": [17, 70, 10, 3, 0],
        "suptitle": "Marital Status"
    },
    {
        "table_name": "Religious Denomination of Participants",
        "response": ["Christianity", "Islam", "Traditional", "Others"],
        "frequency": [87, 13, 0, 0],
        "suptitle": "Religious Denomination of Participants"
    },
    {
        "table_name": "How long is your maternity leave",
        "response": ["2-3 months", "3-4 months", "5-6 months", "6 month and above"],
        "frequency": [0, 33, 51, 16],
        "suptitle": "How long is your maternity leave"
    },
    {
        "table_name": "Number of Children of Participants",
        "response": ["1", "2", "3", "4", "5 and above"],
        "frequency": [17, 13, 14, 30, 26],
        "suptitle": "Number of Children of Participants"
    },
    {
        "table_name": "Age of Participant's Last Child/Children",
        "response": ["0-6 months", "7-11 months", "1-3 years", "4-6 years"],
        "frequency": [26, 14, 31, 29],
        "suptitle": "Age of Participant's Last Child/Children"
    },
    {
        "table_name": "Are you familiar with the concept of exclusive breastfeeding?",
        "response": ["Yes"],
        "frequency": [100],
        "suptitle": "Are you familiar with the concept of exclusive breastfeeding?"
    },
    {
        "table_name": "Which do you prefer?",
        "response": ["Exclusive breastfeeding", "Formula", "Both"],
        "frequency": [89, 5, 6],
        "suptitle": "Which do you prefer?"
    },
    {
        "table_name": "Have you ever practiced exclusive breastfeeding?",
        "response": ["Yes", "No"],
        "frequency": [90, 10],
        "suptitle": "Have you ever practiced exclusive breastfeeding?"
    },
    {
        "table_name": "How often were/are you feeding your baby exclusively?",
        "response": ["4-6 times daily", "As many as possible"],
        "frequency": [3, 97],
        "suptitle": "How often were/are you feeding your baby exclusively?"
    },
    {
        "table_name": "Do you include water to the feeding?",
        "response": ["Yes", "No", "Sometimes"],
        "frequency": [4, 91, 5],
        "suptitle": "Do you include water to the feeding?"
    },
    {
        "table_name": "Are you aware of the recommended duration for exclusive breastfeeding?",
        "response": ["Yes", "No"],
        "frequency": [55, 45],
        "suptitle": "Are you aware of the recommended duration for exclusive breastfeeding?"
    },
    {
        "table_name": "Do you feel the need to sometimes stop breastfeeding exclusively?",
        "response": ["Yes", "No", "Maybe"],
        "frequency": [67, 13, 20],
        "suptitle": "Do you feel the need to sometimes stop breastfeeding exclusively?"
    },
    {
        "table_name": "What may possibly stop you from breastfeeding exclusively?",
        "response": ["Work", "Health issues", "Lack of support"],
        "frequency": [68, 22, 10],
        "suptitle": "What may possibly stop you from breastfeeding exclusively?"
    },
    {
        "table_name": "Do you breastfeed in public?",
        "response": ["Yes", "Not at all", "Sometimes"],
        "frequency": [41, 9, 50],
        "suptitle": "Do you breastfeed in public?"
    },
    {
        "table_name": "Are you allowed to combine work and nursing of baby when necessary?",
        "response": ["Sometimes", "Always", "Not at all"],
        "frequency": [59, 13, 28],
        "suptitle": "Are you allowed to combine work and nursing of baby when necessary?"
    },
    {
        "table_name": "Do you think exclusive breastfeeding promotes your child’s nutritional growth and development?",
        "response": ["Yes"],
        "frequency": [100],
        "suptitle": "Do you think exclusive breastfeeding promotes your child’s nutritional growth and development?"
    },
    {
        "table_name": "Is there any maternity policy in the school?",
        "response": ["Yes", "Not at all"],
        "frequency": [19, 91],
        "suptitle": "Is there any maternity policy in the school?"
    },
    {
        "table_name": "Do you think breastfeeding develops a bond between mothers and baby?",
        "response": ["Always", "Not at all", "Sometimes"],
        "frequency": [53, 10, 37],
        "suptitle": "Do you think breastfeeding develops a bond between mothers and baby?"
    },
    {
        "table_name": "Do you think exclusive breastfeeding saves on cost?",
        "response": ["Yes", "No", "Somehow"],
        "frequency": [67, 13, 20],
        "suptitle": "Do you think exclusive breastfeeding saves on cost?"
    },
    {
        "table_name": "Do you think there is enough education on the importance of exclusive breastfeeding?",
        "response": ["Yes", "No", "Somehow"],
        "frequency": [17, 57, 26],
        "suptitle": "Do you think there is enough education on the importance of exclusive breastfeeding?"
    },
    {
        "table_name": "Do you think schools should support teachers who are exclusively breastfeeding their babies?",
        "response": ["Yes", "No", "Not necessarily"],
        "frequency": [96, 4, 0],
        "suptitle": "Do you think schools should support teachers who are exclusively breastfeeding their babies?"
    },
    {
        "table_name": "Do you think exclusive breastfeeding cuts down mother’s bleeding after delivery?",
        "response": ["Yes", "No", "Not really"],
        "frequency": [60, 15, 25],
        "suptitle": "Do you think exclusive breastfeeding cuts down mother’s bleeding after delivery?"
    },
    {
        "table_name": "Do you think your breast will get sore when you breastfed exclusively?",
        "response": ["Yes", "No", "Maybe"],
        "frequency": [12, 7, 81],
        "suptitle": "Do you think your breast will get sore when you breastfed exclusively?"
    },
    {
        "table_name": "Do you believe exclusive breastfeeding may be beneficial to the mother’s health?",
        "response": ["Always", "Maybe", "Not at all"],
        "frequency": [35, 55, 70],
        "suptitle": "Do you believe exclusive breastfeeding may be beneficial to the mother’s health?"
    },
    {
        "table_name": "Do you think exclusive breastfeeding reduces the chances of getting pregnant shortly after delivery?",
        "response": ["Yes", "No", "Maybe"],
        "frequency": [65, 12, 23],
        "suptitle": "Do you think exclusive breastfeeding reduces the chances of getting pregnant shortly after delivery?"
    },
    {
        "table_name": "Do you think exclusive breastfeeding makes a woman's breast sag?",
        "response": ["Yes", "No", "Not sure"],
        "frequency": [45, 15, 40],
        "suptitle": "Do you think exclusive breastfeeding makes a woman's breast sag?"
    },
    {
        "table_name": "Do you believe in preserving your breast after delivery for a particular period?",
        "response": ["Yes", "No", "Maybe"],
        "frequency": [57, 23, 20],
        "suptitle": "Do you believe in preserving your breast after delivery for a particular period?"
    },
    {
        "table_name": "Do you believe exclusive breastfeeding can prevent breast cancer?",
        "response": ["Yes", "No", "Maybe"],
        "frequency": [65, 10, 25],
        "suptitle": "Do you believe exclusive breastfeeding can prevent breast cancer?"
    },
    {
        "table_name": "Do you think mothers should breastfeed on demand or on schedule?",
        "response": ["On demand", "On schedule"],
        "frequency": [68, 32],
        "suptitle": "Do you think mothers should breastfeed on demand or on schedule?"
    },
    {
        "table_name": "Have you experienced any health issues due to exclusive breastfeeding?",
        "response": ["Yes", "No", "Not sure"],
        "frequency": [25, 65, 10],
        "suptitle": "Have you experienced any health issues due to exclusive breastfeeding?"
    },
    {
        "table_name": "If yes, what kind of health issues?",
        "response": ["Mastitis", "Breast abscess", "Fatigue"],
        "frequency": [5, 15, 5],
        "suptitle": "If yes, what kind of health issues?"
    },
    {
        "table_name": "Do you think exclusive breastfeeding affects your sexual life negatively?",
        "response": ["Yes", "No", "Not sure"],
        "frequency": [45, 40, 15],
        "suptitle": "Do you think exclusive breastfeeding affects your sexual life negatively?"
    },
    {
        "table_name": "Do you think it’s necessary to introduce complementary feeding before 6 months?",
        "response": ["Yes", "No", "Not sure"],
        "frequency": [25, 55, 20],
        "suptitle": "Do you think it’s necessary to introduce complementary feeding before 6 months?"
    },
    {
        "table_name": "How soon after delivery should exclusive breastfeeding commence?",
        "response": ["Immediately", "Within 1 hour", "Within 24 hours", "After 24 hours"],
        "frequency": [10, 40, 35, 15],
        "suptitle": "How soon after delivery should exclusive breastfeeding commence?"
    },
    {
        "table_name": "Do you think men should support their wives in exclusive breastfeeding?",
        "response": ["Yes", "No", "Not sure"],
        "frequency": [75, 20, 5],
        "suptitle": "Do you think men should support their wives in exclusive breastfeeding?"
    },
    {
        "table_name": "What ways do you suggest men can support their wives in exclusive breastfeeding?",
        "response": ["Provide emotional support", "Assist in household chores", "Assist with baby care"],
        "frequency": [55, 25, 20],
        "suptitle": "What ways do you suggest men can support their wives in exclusive breastfeeding?"
    },
    {
        "table_name": "Do you think a woman's diet affects the quality of breast milk?",
        "response": ["Yes", "No", "Not sure"],
        "frequency": [70, 15, 15],
        "suptitle": "Do you think a woman's diet affects the quality of breast milk?"
    },
    {
        "table_name": "Do you think exclusive breastfeeding can delay a woman’s return to fertility?",
        "response": ["Yes", "No", "Not sure"],
        "frequency": [65, 15, 20],
        "suptitle": "Do you think exclusive breastfeeding can delay a woman’s return to fertility?"
    },
    {
        "table_name": "Are you satisfied with the knowledge you have on exclusive breastfeeding?",
        "response": ["Yes", "No", "Not sure"],
        "frequency": [45, 40, 15],
        "suptitle": "Are you satisfied with the knowledge you have on exclusive breastfeeding?"
    },
    {
        "table_name": "Do you think there is enough awareness on exclusive breastfeeding in your community?",
        "response": ["Yes", "No", "Not sure"],
        "frequency": [35, 50, 15],
        "suptitle": "Do you think there is enough awareness on exclusive breastfeeding in your community?"
    },
       {
        "table_name": "Does the school permit you to bring your baby to school?",
        "response": ["Yes", "Not at all", "Sometimes"],
        "frequency": [5, 29, 66,],
        "suptitle": "Does the school permit you to bring your baby to school?"
    }
]


# Now, loop through the table_data list and create distribution charts for each table
for table in table_data:
    response = table['response']
    frequency = table['frequency']
    suptitle = table['suptitle']
    create_distribution(response, frequency, suptitle)
